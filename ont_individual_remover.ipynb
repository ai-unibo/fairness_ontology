# %%
from rdflib import Graph
import pandas as pd
from rdflib import URIRef,Literal
from rdflib.namespace import RDF,RDFS

# %%
prefix="http://fairness_ontology.com/"
g = Graph()
g.parse("./complete-ontologies/fairness_ontology-3.ttl", format='turtle')
print(len(g))
#REMOVING INDIVIDUAL NOTIONS
not_query = """PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX : <http://fairness_ontology.com/> 
    PREFIX fmo: <https://purl.org/twc/fmo#> 
    SELECT ?individual
    WHERE {
    # ?individual rdf:type ?subclass .
    # ?subclass rdfs:subClassOf* fmo:fairness_notion .
    }"""
qres = g.query(not_query)
for row in qres:
    print(f"Removing NOTION {row.individual}")
    g.remove((row.individual, None, None))
    g.remove((None, None, row.individual))
# Out:
# 2421
# Removing NOTION http://fairness_ontology.com/CounterfactualFairness
# Removing NOTION http://fairness_ontology.com/ConditionalStatisticalParity
# Removing NOTION http://fairness_ontology.com/DemographicParity
# Removing NOTION http://fairness_ontology.com/EquityOfAmortizedAttention
# Removing NOTION http://fairness_ontology.com/EquityOfAttention
# Removing NOTION http://fairness_ontology.com/QualityWeightedFairness
# Removing NOTION http://fairness_ontology.com/StatisticalParity
# Removing NOTION http://fairness_ontology.com/TotalFairness
# Removing NOTION http://fairness_ontology.com/UniformFairness
# Removing NOTION http://fairness_ontology.com/BalanceForNegativeClass
# Removing NOTION http://fairness_ontology.com/BalanceForPositiveClass
# Removing NOTION http://fairness_ontology.com/ConditionalEqualOpportunity
# Removing NOTION http://fairness_ontology.com/ConditionalProcedureAccuracyEquality
# Removing NOTION http://fairness_ontology.com/EqualOpportunity
# ...

# %%
#REMOVING INDIVIDUAL METRICS:
not_query = """PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX : <http://fairness_ontology.com/> 
    PREFIX fmo: <https://purl.org/twc/fmo#> 
    SELECT ?individual
    WHERE {
    # ?individual rdf:type ?subclass .
    # ?subclass rdfs:subClassOf* fmo:fairness_metric .
    }"""
qres = g.query(not_query)
for row in qres:
    print(f"Removing METRIC {row.individual}")
    g.remove((row.individual, None, None))
    g.remove((None, None, row.individual))
# Out:
# Removing METRIC http://fairness_ontology.com/FalseDiscoveryRate
# Removing METRIC http://fairness_ontology.com/OutcomeUnfairness
# Removing METRIC http://fairness_ontology.com/TruePositiveRateDifference
# Removing METRIC http://fairness_ontology.com/BalancedConditionedConsistency
# Removing METRIC http://fairness_ontology.com/ConsistencyScore
# Removing METRIC http://fairness_ontology.com/IndividualConsistencyScore
# Removing METRIC http://fairness_ontology.com/LowIndividualConsistencyCount
# Removing METRIC http://fairness_ontology.com/ProportionalConsistencyScore
# Removing METRIC http://fairness_ontology.com/RelativeLInfiniteMetric
# Removing METRIC http://fairness_ontology.com/SimilarityRobustnessOfIndividualConsistency
# Removing METRIC http://fairness_ontology.com/TotalVariationNorm
# Removing METRIC http://fairness_ontology.com/CEAT
# Removing METRIC http://fairness_ontology.com/SEAT
# Removing METRIC http://fairness_ontology.com/SentenceBiasScore
# ...

# %%
#REMOVING MIT TECH
not_query = """PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX : <http://fairness_ontology.com/> 
    PREFIX fmo: <https://purl.org/twc/fmo#> 
    SELECT ?individual
    WHERE {
    # ?individual rdf:type ?subclass .
    # ?subclass rdfs:subClassOf* :MitigationTechnique .
    }"""
qres = g.query(not_query)
for row in qres:
    print(f"Removing MIT TECH{row.individual}")
    g.remove((row.individual, None, None))
    g.remove((None, None, row.individual))
# Out:
# Removing MIT TECHhttp://fairness_ontology.com/AddNonToxicExamples
# Removing MIT TECHhttp://fairness_ontology.com/FairGAN
# Removing MIT TECHhttp://fairness_ontology.com/DisadvantagedTextCollection
# Removing MIT TECHhttp://fairness_ontology.com/LowBiasJobAdv
# Removing MIT TECHhttp://fairness_ontology.com/BalancedTraining
# Removing MIT TECHhttp://fairness_ontology.com/ReSamplingProtectedGroup
# Removing MIT TECHhttp://fairness_ontology.com/BlocklistDocumentRemoval
# Removing MIT TECHhttp://fairness_ontology.com/LogLikeDocumentRemoval
# Removing MIT TECHhttp://fairness_ontology.com/AugmentedAntidoteData
# Removing MIT TECHhttp://fairness_ontology.com/CDA
# Removing MIT TECHhttp://fairness_ontology.com/CDS
# Removing MIT TECHhttp://fairness_ontology.com/NamesIntervention
# Removing MIT TECHhttp://fairness_ontology.com/OSCAR
# Removing MIT TECHhttp://fairness_ontology.com/ControlOffensiveTokens
# Removing MIT TECHhttp://fairness_ontology.com/RedistributeProb
# ...

# %%
#REMOVE PAPERS
not_query = """PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX : <http://fairness_ontology.com/> 
    SELECT ?individual
    WHERE {
    # ?individual rdf:type ?subclass .
    # ?subclass rdfs:subClassOf* :ScientificPaper .
    }"""
qres = g.query(not_query)
for row in qres:
    print(f"Removing PAPERS{row.individual}")
    g.remove((row.individual, None, None))
    g.remove((None, None, row.individual))
# Out:
# Removing PAPERShttp://fairness_ontology.com/1951_KULLBACK
# Removing PAPERShttp://fairness_ontology.com/1984_JAIN
# Removing PAPERShttp://fairness_ontology.com/2012_DWORK
# Removing PAPERShttp://fairness_ontology.com/2012_KAMISHIMA
# Removing PAPERShttp://fairness_ontology.com/2013_ZEMEL
# Removing PAPERShttp://fairness_ontology.com/2015_FELDMAN
# Removing PAPERShttp://fairness_ontology.com/2016_DIETERICH
# Removing PAPERShttp://fairness_ontology.com/2016_GRGIC-HLACA
# Removing PAPERShttp://fairness_ontology.com/2016_HARDT
# Removing PAPERShttp://fairness_ontology.com/2017_CALISKAN
# Removing PAPERShttp://fairness_ontology.com/2017_CHOULDECHOVA
# Removing PAPERShttp://fairness_ontology.com/2017_CORBETT-DAVIES
# Removing PAPERShttp://fairness_ontology.com/2017_KLEINBERG
# Removing PAPERShttp://fairness_ontology.com/2017_KUSNER
# Removing PAPERShttp://fairness_ontology.com/2017_LIN
# Removing PAPERShttp://fairness_ontology.com/2017_MODANI
# ...

# %%
#REMOVE ARTICLES
not_query = """PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX : <http://fairness_ontology.com/> 
    SELECT ?individual
    WHERE {
    # ?individual rdf:type ?subclass .
    # ?subclass rdfs:subClassOf* :LegalRequirement .
    }"""
qres = g.query(not_query)
for row in qres:
    print(f"Removing PAPERS{row.individual}")
    g.remove((row.individual, None, None))
    g.remove((None, None, row.individual))
# Out:
# Removing PAPERShttp://fairness_ontology.com/Art.10.5
# Removing PAPERShttp://fairness_ontology.com/Art.11
# Removing PAPERShttp://fairness_ontology.com/Art.112.10
# Removing PAPERShttp://fairness_ontology.com/Art.13
# Removing PAPERShttp://fairness_ontology.com/Art.14
# Removing PAPERShttp://fairness_ontology.com/Art.16
# Removing PAPERShttp://fairness_ontology.com/Art.17
# Removing PAPERShttp://fairness_ontology.com/Art.2
# Removing PAPERShttp://fairness_ontology.com/Art.20
# Removing PAPERShttp://fairness_ontology.com/Art.21
# Removing PAPERShttp://fairness_ontology.com/Art.23
# Removing PAPERShttp://fairness_ontology.com/Art.24
# Removing PAPERShttp://fairness_ontology.com/Art.25
# Removing PAPERShttp://fairness_ontology.com/Art.26
# Removing PAPERShttp://fairness_ontology.com/Art.27
# Removing PAPERShttp://fairness_ontology.com/Art.29
# Removing PAPERShttp://fairness_ontology.com/Art.3
# Removing PAPERShttp://fairness_ontology.com/Art.4
# ...

# %%
g.serialize(destination="FO3_no_ind.ttl")
# Out:
# <Graph identifier=N96f14e56a6d644c89799c5dafc763f20 (<class 'rdflib.graph.Graph'>)>

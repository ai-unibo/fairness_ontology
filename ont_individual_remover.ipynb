# %%
from rdflib import Graph
import pandas as pd
from rdflib import URIRef,Literal
from rdflib.namespace import RDF,RDFS

# %%
prefix="http://fairness_ontology.com/"
g = Graph()
g.parse("./complete-ontologies/fairness_ontology-3.ttl", format='turtle')
print(len(g))
#REMOVING INDIVIDUAL NOTIONS
not_query = """PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX : <http://fairness_ontology.com/> 
    PREFIX fmo: <https://purl.org/twc/fmo#> 
    SELECT ?individual
    WHERE {
    # ?individual rdf:type ?subclass .
    # ?subclass rdfs:subClassOf* fmo:fairness_notion .
    }"""
qres = g.query(not_query)
for row in qres:
    print(f"Removing {row.individual}")
    g.remove((row.individual, None, None))
    g.remove((None, None, row.individual))

#REMOVING INDIVIDUAL METRICS:
not_query = """PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX : <http://fairness_ontology.com/> 
    PREFIX fmo: <https://purl.org/twc/fmo#> 
    SELECT ?individual
    WHERE {
    # ?individual rdf:type ?subclass .
    # ?subclass rdfs:subClassOf* fmo:fairness_metric .
    }"""
qres = g.query(not_query)
for row in qres:
    print(f"Removing {row.individual}")
    g.remove((row.individual, None, None))
    g.remove((None, None, row.individual))

#REMOVE MIT TECH
#REMOVE PAPERS


g.serialize(destination="tbl.ttl")
# Out:
# 1659
# Removing http://fairness_ontology.com/CounterfactualFairness
# Removing http://fairness_ontology.com/ConditionalStatisticalParity
# Removing http://fairness_ontology.com/DemographicParity
# Removing http://fairness_ontology.com/StatisticalParity
# Removing http://fairness_ontology.com/TotalFairness
# Removing http://fairness_ontology.com/BalanceForNegativeClass
# Removing http://fairness_ontology.com/BalanceForPositiveClass
# Removing http://fairness_ontology.com/ConditionalEqualOpportunity
# Removing http://fairness_ontology.com/ConditionalProcedureAccuracyEquality
# Removing http://fairness_ontology.com/EqualOpportunity
# Removing http://fairness_ontology.com/EqualizedOdds
# Removing http://fairness_ontology.com/EqualizingDisincentives
# Removing http://fairness_ontology.com/ErrorRateBalance
# Removing http://fairness_ontology.com/FalseNegativeErrorRateBalance
# Removing http://fairness_ontology.com/FalsePositiveErrorRateBalance
# Removing http://fairness_ontology.com/OverallAccuracyEquality
# Removing http://fairness_ontology.com/PredictiveEquality
# Removing http://fairness_ontology.com/TreatmentEquality
# Removing http://fairness_ontology.com/Calibration
# Removing http://fairness_ontology.com/ConditionalUseAccuracyEquality
# Removing http://fairness_ontology.com/MatchingConditionalFrequencies
# Removing http://fairness_ontology.com/PredictiveParity
# Removing http://fairness_ontology.com/TestFairness
# Removing http://fairness_ontology.com/WellCalibration
# Removing http://fairness_ontology.com/FairnessThroughAwareness
# Removing http://fairness_ontology.com/IndividualFairness
# Removing http://fairness_ontology.com/FairnessThroughUnawareness
# Removing http://fairness_ontology.com/BalancedConditionedConsistency
# Removing http://fairness_ontology.com/ConsistencyScore
# Removing http://fairness_ontology.com/FairScore
# Removing http://fairness_ontology.com/GeneralizedEntropyIndex
# Removing http://fairness_ontology.com/IndividualConsistencyScore
# Removing http://fairness_ontology.com/LowIndividualConsistencyCount
# Removing http://fairness_ontology.com/ProportionalConsistencyScore
# Removing http://fairness_ontology.com/SimilarityRobustnessOfIndividualConsistency
# Removing http://fairness_ontology.com/TheilIndex
# Removing http://fairness_ontology.com/OutcomeUnfairness
# Removing http://fairness_ontology.com/CEAT
# Removing http://fairness_ontology.com/SEAT
# Removing http://fairness_ontology.com/SentenceBiasScore
# Removing http://fairness_ontology.com/WEAT
# Removing http://fairness_ontology.com/CounterfactualSentimentBias
# Removing http://fairness_ontology.com/EmpiricalToxicityProbability
# Removing http://fairness_ontology.com/ExpectedMaximumToxicity
# Removing http://fairness_ontology.com/FullGenBias
# Removing http://fairness_ontology.com/PerspectiveAPI
# Removing http://fairness_ontology.com/RegardScore
# Removing http://fairness_ontology.com/ScoreParity
# Removing http://fairness_ontology.com/ToxicityFraction
# Removing http://fairness_ontology.com/CoOccurrenceBiasScore
# Removing http://fairness_ontology.com/DemographicRepresentation
# Removing http://fairness_ontology.com/SocialGroupSubstitution
# Removing http://fairness_ontology.com/StereotypicalAssociations
# Removing http://fairness_ontology.com/GenderPolarity
# Removing http://fairness_ontology.com/HONEST
# Removing http://fairness_ontology.com/PsycholinguisticNorms
# Removing http://fairness_ontology.com/DisparateImpact
# Removing http://fairness_ontology.com/TruePositiveRateDifference
# Removing http://fairness_ontology.com/CategoricalBiasScore
# Removing http://fairness_ontology.com/DisCo
# Removing http://fairness_ontology.com/LogProbabilityBiasScore
# Removing http://fairness_ontology.com/AllUnmaskedLikelihood
# Removing http://fairness_ontology.com/ContextAssociationTest
# Removing http://fairness_ontology.com/CrowSPairsScore
# Removing http://fairness_ontology.com/LanguageModelBias
# Removing http://fairness_ontology.com/BayesianFairness
# <Graph identifier=N8c94d9e6c45a4185aef298b17c16a257 (<class 'rdflib.graph.Graph'>)>
